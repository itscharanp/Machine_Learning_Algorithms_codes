# %%
import pandas as pd

# %%
play=pd.read_csv('C:/Users/welcome/Desktop/playdata.csv')

# %%
play.head()
# Out:
#    DAY   OUTLOOK    TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY     HOT     HIGH    WEAK         1
# 1    2     SUNNY     HOT     HIGH  STRONG         1
# 2    3  OVERCAST     HOT     HIGH    WEAK         2
# 3    4      RAIN     HOT     HIGH    WEAK         2
# 4    5      RAIN  NORMAL   NORMAL    WEAK         2

# %%
play.loc[0,:]
# Out:
# DAY             1
# OUTLOOK     SUNNY
# TEMP          HOT
# HUMIDITY     HIGH
# WIND         WEAK
# PLAYBOLL        1
# Name: 0, dtype: object

# %%
play.loc[[0,1,2],:]
# Out:
#    DAY   OUTLOOK TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY  HOT     HIGH    WEAK         1
# 1    2     SUNNY  HOT     HIGH  STRONG         1
# 2    3  OVERCAST  HOT     HIGH    WEAK         2

# %%
play.loc[0:2,:]
# Out:
#    DAY   OUTLOOK TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY  HOT     HIGH    WEAK         1
# 1    2     SUNNY  HOT     HIGH  STRONG         1
# 2    3  OVERCAST  HOT     HIGH    WEAK         2

# %%
play.loc[1:4,['TEMP','HUMIDITY']]
# Out:
#      TEMP HUMIDITY
# 1     HOT     HIGH
# 2     HOT     HIGH
# 3     HOT     HIGH
# 4  NORMAL   NORMAL

# %%
play.loc[1:4,'DAY':'WIND']
# Out:
#    DAY   OUTLOOK    TEMP HUMIDITY    WIND
# 1    2     SUNNY     HOT     HIGH  STRONG
# 2    3  OVERCAST     HOT     HIGH    WEAK
# 3    4      RAIN     HOT     HIGH    WEAK
# 4    5      RAIN  NORMAL   NORMAL    WEAK

# %%
play.head(3).drop('TEMP',axis=1)
# Out:
#    DAY   OUTLOOK HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY     HIGH    WEAK         1
# 1    2     SUNNY     HIGH  STRONG         1
# 2    3  OVERCAST     HIGH    WEAK         2

# %%
play.head()
# Out:
#    DAY   OUTLOOK    TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY     HOT     HIGH    WEAK         1
# 1    2     SUNNY     HOT     HIGH  STRONG         1
# 2    3  OVERCAST     HOT     HIGH    WEAK         2
# 3    4      RAIN     HOT     HIGH    WEAK         2
# 4    5      RAIN  NORMAL   NORMAL    WEAK         2

# %%
play[play.TEMP=='NORMAL']
# Out:
#     DAY   OUTLOOK    TEMP HUMIDITY    WIND  PLAYBOLL
# 4     5      RAIN  NORMAL   NORMAL    WEAK         2
# 5     6      RAIN  NORMAL   NORMAL  STRONG         1
# 6     7  OVERCAST  NORMAL   NORMAL  STRONG         2
# 8     9     SUNNY  NORMAL   NORMAL    WEAK         2
# 9    10      RAIN  NORMAL   NORMAL    WEAK         2
# 10   11     SUNNY  NORMAL   NORMAL  STRONG         2
# 12   13  OVERCAST  NORMAL   NORMAL    WEAK         2

# %%
play.loc[play.TEMP=='HOT','WIND']
# Out:
# 0      WEAK
# 1    STRONG
# 2      WEAK
# 3      WEAK
# Name: WIND, dtype: object

# %%
play[play.TEMP=='HOT'].WIND
# Out:
# 0      WEAK
# 1    STRONG
# 2      WEAK
# 3      WEAK
# Name: WIND, dtype: object

# %%
play.head()
# Out:
#    DAY   OUTLOOK    TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY     HOT     HIGH    WEAK         1
# 1    2     SUNNY     HOT     HIGH  STRONG         1
# 2    3  OVERCAST     HOT     HIGH    WEAK         2
# 3    4      RAIN     HOT     HIGH    WEAK         2
# 4    5      RAIN  NORMAL   NORMAL    WEAK         2

# %%
play.iloc[:,[0,3]]
# Out:
#     DAY HUMIDITY
# 0     1     HIGH
# 1     2     HIGH
# 2     3     HIGH
# 3     4     HIGH
# 4     5   NORMAL
# 5     6   NORMAL
# 6     7   NORMAL
# 7     8     HIGH
# 8     9   NORMAL
# 9    10   NORMAL
# 10   11   NORMAL
# 11   12     HIGH
# 12   13   NORMAL
# 13   14     HIGH

# %%
play.columns
# Out:
# Index(['DAY', 'OUTLOOK', 'TEMP', 'HUMIDITY', 'WIND', 'PLAYBOLL'], dtype='object')

# %%
list(range(0,5))
# Out:
# [0, 1, 2, 3, 4]

# %%
play.iloc[0:3,:]
# Out:
#    DAY   OUTLOOK TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY  HOT     HIGH    WEAK         1
# 1    2     SUNNY  HOT     HIGH  STRONG         1
# 2    3  OVERCAST  HOT     HIGH    WEAK         2

# %%
play.iloc[0:3,:]
# Out:
#    DAY   OUTLOOK TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1     SUNNY  HOT     HIGH    WEAK         1
# 1    2     SUNNY  HOT     HIGH  STRONG         1
# 2    3  OVERCAST  HOT     HIGH    WEAK         2

# %%
play[['TEMP','WIND']]
# Out:
#       TEMP    WIND
# 0      HOT    WEAK
# 1      HOT  STRONG
# 2      HOT    WEAK
# 3      HOT    WEAK
# 4   NORMAL    WEAK
# 5   NORMAL  STRONG
# 6   NORMAL  STRONG
# 7     HIGH    WEAK
# 8   NORMAL    WEAK
# 9   NORMAL    WEAK
# 10  NORMAL  STRONG
# 11    HIGH  STRONG
# 12  NORMAL    WEAK
# 13    HIGH  STRONG

# %%
play[0:2]
# Out:
#    DAY OUTLOOK TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1   SUNNY  HOT     HIGH    WEAK         1
# 1    2   SUNNY  HOT     HIGH  STRONG         1

# %%
play.iloc[0:2,:]
# Out:
#    DAY OUTLOOK TEMP HUMIDITY    WIND  PLAYBOLL
# 0    1   SUNNY  HOT     HIGH    WEAK         1
# 1    2   SUNNY  HOT     HIGH  STRONG         1
